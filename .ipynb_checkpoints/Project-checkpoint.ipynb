# %%
import sys
# !{sys.executable} -m pip install autograd
# Out:
# Requirement already satisfied: autograd in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (1.7.0)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from autograd) (1.26.4)

# %%
# !pip install tensorflow-macos tensorflow-metal
# Out:
# Requirement already satisfied: tensorflow-macos in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (2.16.2)
# Requirement already satisfied: tensorflow-metal in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (1.1.0)
# Requirement already satisfied: tensorflow==2.16.2 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from tensorflow-macos) (2.16.2)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (3.4.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (2.32.3)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.68.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (3.7.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.26.4)
# Requirement already satisfied: wheel~=0.35 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from tensorflow-metal) (0.44.0)
# Requirement already satisfied: rich in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (13.9.4)
# Requirement already satisfied: namex in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (0.0.8)
# Requirement already satisfied: optree in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (0.1.2)

# %%
import tensorflow as tf

print("TensorFlow version:", tf.__version__)
print("Available devices:", tf.config.list_physical_devices())
# Out:
# TensorFlow version: 2.16.2
# Available devices: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !pip install scikit-learn
# !pip install matplotlib
# !pip install pandas
# Out:
# Requirement already satisfied: scikit-learn in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (3.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from matplotlib) (4.55.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/tensorflow_env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import autograd.numpy as np
import numpy as numpy
from autograd import grad, elementwise_grad
from sklearn.linear_model import LinearRegression, Lasso
import matplotlib.pylab as plt
import pandas as pd

# %%
###Utility Functions###
def generate_perturbed_X(X, delta, sampling, S, seed=0):
    np.random.seed(seed=seed)
    N = X.shape[0]
    D = X.shape[1]

    X_expanded = X[np.newaxis, :, :]
    if sampling == 'normal':
         epsilon_s = np.random.normal(0 , delta, size=(S, N, D))
         X_perturbed =  X_expanded + epsilon_s
    elif sampling == 'logitnormal':

        epsilon = 1e-6
        X_clipped = np.clip(X_expanded, epsilon, 1 - epsilon)
        # Apply the logit function to get log-odds
        X_logit = logit(X_clipped)

        # Correct noise shape here, broadcast compatible with `X_logit`
        noise_shape = (S, N, D)
        noise = np.random.normal(0, delta, size=noise_shape)

        # Add Gaussian noise to the log-odds
        noisy_X_logit = X_logit + noise

        # Convert back to probabilities and round the result if needed
        X_perturbed = expit(noisy_X_logit)
    else:
        raise  Exception('Sampling {} not defined,'.format('sampling'))

    return X_perturbed

# %%
def similarity(X_perturbed, X_original, sigma=2):
    '''
    kernel_fn: computes the similarity between perturbed inputs and the original input
    input:
        X_perturbed(S, D): S perturbed versions of the input, each with D features
        X_original(D): the original input
        sigma: bandwidth for the Gaussian kernel
    output:
        pi_x(S): array of similarity scores for each perturbed sample
    '''
    distance = np.linalg.norm(X_perturbed - X_original, axis=1)
    pi_x = np.exp(-distance ** 2 / (sigma ** 2))

    return pi_x

# %%
def compute_LIME_explanations(X, X_perturbed, fn, y_sample):
    """
    Compute a matrix of explanations for each sample.
    Parameters:
        X (np.array): Original dataset of shape (N, D).
        X_perturbed (np.array): Perturbed inputs of shape (S, N, D).
        fn (function): Model to explain.
        y_sample (np.array): Target classes for each sample in X.
    Returns:
        np.array: Explanations matrix of shape (N, D).
    """
    S, N, D = X_perturbed.shape
    Explanations = np.zeros((N, D))
    linear_model = LinearRegression()  # Instantiate the regression model once
    # lasso_model = Lasso(alpha=0.001, max_iter=1000)

    for i in range(N):
        print(i)
        perturbed_sample_i = X_perturbed[:, i, :]
        target = fn(perturbed_sample_i)
        # Extract the revelant score for the corresponding class
        target_class = target[:, y_sample[i]]

        # Compute coefficients for the current sample
        pi_x = similarity(perturbed_sample_i, X[i])
        linear_model.fit(perturbed_sample_i, target_class, sample_weight=pi_x)

        # lasso_model.fit(perturbed_sample_i, target_class, sample_weight=pi_x) 
        # coef = lasso_model.coef_
        
        coef = linear_model.coef_
        Explanations[i, :] = np.abs(coef)  # Store absolute values of coefficients

    return Explanations

# %%
def generate_perturbed_conv_outputs(conv_model, X, delta, sampling, S, seed=0):
    """
    Generate perturbed convolutional outputs for a given convolutional model.

    Parameters:
        conv_model (keras.Model): The intermediate model for convolutional layer outputs.
        X (np.array): Original dataset of shape (N, H, W, C).
        delta (float): Perturbation scale.
        sampling (str): Type of perturbation ('normal' or 'logitnormal').
        S (int): Number of perturbed samples.
        seed (int): Random seed for reproducibility.

    Returns:
        np.array: Perturbed convolutional outputs of shape (S, N, H, W, C).
    """
    np.random.seed(seed)
    conv_outputs = conv_model.predict(X)  # Extract convolutional outputs
    N, H, W, C = conv_outputs.shape

    if sampling == 'normal':
        epsilon_s = np.random.normal(0, delta, size=(S, N, H, W, C))
        perturbed_outputs = conv_outputs[np.newaxis, :, :, :, :] + epsilon_s
    elif sampling == 'logitnormal':
        raise NotImplementedError("Logit-normal sampling is not implemented for convolutional outputs.")
    else:
        raise ValueError(f"Sampling method '{sampling}' is not defined.")

    return perturbed_outputs

# %%
def compute_conv_LIME_explanations(conv_outputs, conv_outputs_perturbed, fn, y_sample):
    """
    Compute explanations for convolutional feature maps.

    Parameters:
        conv_outputs (np.array): Original convolutional outputs of shape (N, H, W, C).
        conv_outputs_perturbed (np.array): Perturbed convolutional outputs of shape (S, N, H, W, C).
        fn (function): Sub-model function to compute predictions.
        y_sample (np.array): Target classes for each sample.

    Returns:
        np.array: Explanations matrix of shape (N, C).
    """
    S, N, H, W, C = conv_outputs_perturbed.shape
    explanations = np.zeros((N, C))  # Store explanations for each feature map
    linear_model = LinearRegression()  # Instantiate the regression model once

    for i in range(N):
        print(i)
        perturbed_sample_i = conv_outputs_perturbed[:, i, :, :, :]  # Shape: (S, H, W, C)
        perturbed_sample_i_flat = perturbed_sample_i.reshape(S, -1)  # Shape: (S, H * W * C)
        original_sample_flat = conv_outputs[i].reshape(-1)  # Shape: (H * W * C)

        # Predict target outputs for perturbed samples
        target = fn(perturbed_sample_i)  # Shape: (S, num_classes)
        target_class = target[:, y_sample[i]]  # Relevant scores for the class of interest

        # Compute similarity weights
        pi_x = similarity(perturbed_sample_i_flat, original_sample_flat)

        # Fit the linear model to compute explanations
        linear_model.fit(perturbed_sample_i_flat, target_class, sample_weight=pi_x)

        # Store absolute coefficients as feature importance
        coef = linear_model.coef_.reshape(H, W, C)  # Reshape to match spatial dimensions
        explanations[i, :] = np.abs(coef.mean(axis=(0, 1)))  # Aggregate over spatial dimensions

    return explanations

# %%
def LIME_global_mean(explanations, y_sample=None, class_of_interest=None):
    """
    Compute the mean explanation for all samples, or filter by class if specified.
    Parameters:
        explanations (np.array): Explanation matrix of shape (N, D).
        y_sample (np.array, optional): Array of true class labels of shape (N,). Required if filtering by class.
        class_of_interest (int, optional): The class for which to filter explanations.
    Returns:
        np.array: Mean explanation vector of shape (D,).
    """
    if class_of_interest is not None:
        if y_sample is None:
            raise ValueError("y_sample must be provided if class_of_interest is specified.")
        
        # Filter explanations for the class of interest
        target_indices = y_sample == class_of_interest
        filtered_explanations = explanations[target_indices, :]
        # Compute the mean explanation for the filtered data
        mean_explanation = np.mean(filtered_explanations, axis=0)
    else:
        # Compute the mean explanation for all samples
        mean_explanation = np.mean(exp, axis=0)
    
    return mean_explanation

# %%
def LIME_global_paper(explanations, y_sample=None, class_of_interest=None):
    """
    Aggregate the explanations matrix using the formula sqrt(sum(|W_ij|)) for each feature.
    If class_of_interest is specified, filters the explanations first.
    Parameters:
        explanations (np.array): Explanation matrix of shape (N, D).
        y_sample (np.array, optional): Array of true class labels of shape (N,).
        class_of_interest (int, optional): The class for which to filter explanations.
    Returns:
        np.array: Aggregated explanations of shape (D,).
    """
    if class_of_interest is not None:
        if y_sample is None:
            raise ValueError("y_sample must be provided if class_of_interest is specified.")
        # Filter explanations for the class of interest
        target_indices = y_sample == class_of_interest
        explanations = explanations[target_indices, :]
    
    # Compute the aggregation for each feature
    return np.sqrt(np.sum(np.abs(explanations), axis=0))

# %%
def LIME_global_normalization(explanations, y_sample=None, class_of_interest=None):
    """
    Compute global LIME explanations by aggregating over all samples with normalization.
    If class_of_interest is specified, filters the explanations first.
    Parameters:
        explanations (np.array): Explanation matrix of shape (N, D).
        y_sample (np.array, optional): Array of true class labels of shape (N,).
        class_of_interest (int, optional): The class for which to filter explanations.
    Returns:
        np.array: Normalized global explanations of shape (D,).
    """
    if class_of_interest is not None:
        if y_sample is None:
            raise ValueError("y_sample must be provided if class_of_interest is specified.")
        # Filter explanations for the class of interest
        target_indices = y_sample == class_of_interest
        explanations = explanations[target_indices, :]

    # Compute normalized global explanations
    non_zero = np.sum(explanations > 0, axis=0)
    non_zero_sum = np.sum(explanations, axis=0)
    Global = non_zero_sum / non_zero
    Global[np.isnan(Global)] = 0  # Handle division by zero

    return Global

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist
import numpy as np
from scipy.special import expit, logit
import matplotlib.pyplot as plt

# %%
# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize data
x_train, x_test = x_train / 255.0, x_test / 255.0

# Reshape data to add channel dimension
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

print(f"x_train shape: {x_train.shape}, x_test shape: {x_test.shape}")
# Out:
# x_train shape: (60000, 28, 28, 1), x_test shape: (10000, 28, 28, 1)

# %%
from tensorflow.keras import layers, models

# Define the model
model = models.Sequential([
    # Block 1: Convolution + MaxPooling
    layers.Input(shape=(28, 28, 1)),  # Explicit Input layer
    layers.Conv2D(32, (3, 3), activation='relu', name='conv2d_1'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # Block 2: Convolution + MaxPooling
    layers.Conv2D(64, (3, 3), activation='relu', name='conv2d_2'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # Fully Connected Layers
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(10, activation='softmax')  # Output layer for classification
])

# Print the model summary
model.summary()
# Out:
# 2024-12-07 20:40:50.409248: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2024-12-07 20:40:50.409278: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-12-07 20:40:50.409289: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-12-07 20:40:50.409647: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-07 20:40:50.409667: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_1 (Conv2D)               │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 241,546 (943.54 KB)
#  Trainable params: 241,546 (943.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=20, validation_split=0.1)
# Out:
# Epoch 1/20
# 2024-12-07 20:40:53.529144: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 25s 14ms/step - accuracy: 0.6956 - loss: 1.1007 - val_accuracy: 0.9695 - val_loss: 0.2596
# Epoch 2/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 25s 15ms/step - accuracy: 0.8997 - loss: 1.2243 - val_accuracy: 0.9758 - val_loss: 0.5744
# Epoch 3/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 24s 14ms/step - accuracy: 0.9127 - loss: 3.1232 - val_accuracy: 0.9730 - val_loss: 2.6083
# Epoch 4/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 24s 14ms/step - accuracy: 0.9214 - loss: 9.5290 - val_accuracy: 0.9748 - val_loss: 5.5268
# Epoch 5/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 24s 14ms/step - accuracy: 0.9301 - loss: 18.4017 - val_accuracy: 0.9808 - val_loss: 7.8102
# Epoch 6/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 23s 14ms/step - accuracy: 0.9350 - loss: 31.3709 - val_accuracy: 0.9805 - val_loss: 13.4014
# Epoch 7/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 24s 14ms/step - accuracy: 0.9398 - loss: 44.5368 - val_accuracy: 0.9810 - val_loss: 18.7525
# Epoch 8/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 24s 14ms/step - accuracy: 0.9417 - loss: 59.0282 - val_accuracy: 0.9800 - val_loss: 23.7010
# Epoch 9/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 24s 14ms/step - accuracy: 0.9430 - loss: 84.3725 - val_accuracy: 0.9860 - val_loss: 31.6280
# Epoch 10/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 23s 14ms/step - accuracy: 0.9442 - loss: 116.4122 - val_accuracy: 0.9830 - val_loss: 46.4399
# Epoch 11/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 24s 14ms/step - accuracy: 0.9467 - loss: 145.8542 - val_accuracy: 0.9817 - val_loss: 69.4706
# Epoch 12/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 23s 14ms/step - accuracy: 0.9491 - loss: 185.1118 - val_accuracy: 0.9822 - val_loss: 76.7324
# Epoch 13/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 23s 13ms/step - accuracy: 0.9507 - loss: 213.8940 - val_accuracy: 0.9813 - val_loss: 113.7530
# Epoch 14/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 23s 14ms/step - accuracy: 0.9503 - loss: 268.5007 - val_accuracy: 0.9833 - val_loss: 114.1641
# Epoch 15/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 24s 14ms/step - accuracy: 0.9486 - loss: 332.6299 - val_accuracy: 0.9858 - val_loss: 117.9727
# Epoch 16/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 23s 14ms/step - accuracy: 0.9477 - loss: 397.7443 - val_accuracy: 0.9838 - val_loss: 177.9230
# Epoch 17/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 23s 14ms/step - accuracy: 0.9512 - loss: 467.7020 - val_accuracy: 0.9862 - val_loss: 184.9845
# Epoch 18/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 23s 14ms/step - accuracy: 0.9521 - loss: 548.4739 - val_accuracy: 0.9860 - val_loss: 212.7848
# Epoch 19/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 23s 14ms/step - accuracy: 0.9522 - loss: 645.0805 - val_accuracy: 0.9828 - val_loss: 248.9097
# Epoch 20/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 24s 14ms/step - accuracy: 0.9514 - loss: 748.7388 - val_accuracy: 0.9863 - val_loss: 307.9584

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_accuracy}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9793 - loss: 346.3886
# Test accuracy: 0.9839000105857849

# %%
sampling = "normal"
S = 1000
delta = 0.25
num_points = 500

# Take a subset of test data to explain
indices = np.random.choice(x_test.shape[0], num_points, replace=False)
x_sample = x_test[indices]
y_sample = y_test[indices]

N = x_sample.shape[0]
X = x_sample.reshape(x_sample.shape[0], -1)
D = X.shape[1]
X_perturbed = generate_perturbed_X(X, delta, sampling, S)

fn = lambda x: model.predict(x.reshape(x.shape[0], 28, 28, 1))

# %%
import numpy as np
from tensorflow.keras import layers, Model

# Step 1: Define the model using Functional API
inputs = layers.Input(shape=(28, 28, 1))
x = layers.Conv2D(32, (3, 3), activation='relu', name='conv2d_1')(inputs)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Dropout(0.25)(x)

x = layers.Conv2D(64, (3, 3), activation='relu', name='conv2d_2')(x)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Dropout(0.25)(x)

x = layers.Flatten()(x)
x = layers.Dense(128, activation='relu')(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(128, activation='relu')(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(10, activation='softmax')(x)

model = Model(inputs=inputs, outputs=outputs)

# Step 2: Initialize model with dummy input
dummy_input = np.random.rand(1, 28, 28, 1).astype(np.float32)
_ = model(dummy_input)  # Call the model to initialize layers

# Step 3: Extract outputs from `conv2d_2`
conv_model = Model(inputs=model.input, outputs=model.get_layer('conv2d_2').output)

# Build the remaining model starting from `conv2d_2`
conv_output = conv_model.output
x = conv_output

start_index = model.layers.index(model.get_layer('conv2d_2')) + 1
for layer in model.layers[start_index:]:
    x = layer(x)

remaining_model = Model(inputs=conv_model.output, outputs=x)

# Step 4: Generate perturbed outputs
S_conv = 200
indices_conv = np.random.choice(x_test.shape[0], num_points, replace=False)
x_sample_conv = x_test[indices_conv]
y_sample_conv = y_test[indices_conv]

conv_outputs = conv_model.predict(x_sample_conv)
conv_outputs_perturbed = generate_perturbed_conv_outputs(conv_model, x_sample_conv, delta, sampling, S_conv)

# Define `fn_conv` to use `remaining_model` for predictions
fn_conv = lambda x: remaining_model.predict(x)

# Test the full model on a sample
full_predictions = model.predict(x_sample_conv)
full_accuracy = np.mean(np.argmax(full_predictions, axis=1) == y_sample_conv)
print(f"Full model accuracy: {full_accuracy * 100:.2f}%")

# Test conv_model + remaining_model combination
conv_outputs = conv_model.predict(x_sample_conv)
combined_predictions = remaining_model.predict(conv_outputs)
combined_accuracy = np.mean(np.argmax(combined_predictions, axis=1) == y_sample_conv)
print(f"Combined model accuracy: {combined_accuracy * 100:.2f}%")
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Full model accuracy: 10.60%
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Combined model accuracy: 10.60%

# %%
explanations = compute_LIME_explanations(X, X_perturbed, fn, y_sample)
# Out:
# 0
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 4
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 8
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 9
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 11
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 14
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 16
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 17
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 18
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 19
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 21
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 23
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 24
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 26
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 27
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 28
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 29
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 31
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 33
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 34
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 35
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 36
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 37
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 38
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 39
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 40
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 41
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 42
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 43
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 44
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 45
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 46
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 47
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 48
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 49
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 51
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 52
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 53
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 54
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 55
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 56
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 57
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 58
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 59
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 60
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 61
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 62
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 63
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 65
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 66
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 67
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 68
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 69
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 71
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 72
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 73
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 74
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 75
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 76
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 77
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 78
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 79
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 80
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 81
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 82
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 83
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 84
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 85
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 86
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 87
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 88
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 89
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 90
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 91
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 92
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 93
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 94
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 95
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 96
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 97
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 98
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 99
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 101
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 102
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 103
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 104
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 105
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 106
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 107
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 108
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 109
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 110
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 111
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 112
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 113
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 114
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 115
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 116
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 117
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 118
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 119
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 121
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 122
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 123
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 124
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 125
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 126
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 127
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 128
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 129
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 130
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 131
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 132
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 133
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 134
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 135
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 136
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 137
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 138
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 139
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 140
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 141
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 142
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 143
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 144
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 145
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 146
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 147
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 148
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 149
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 151
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 152
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 153
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 154
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 155
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 156
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 157
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 158
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 159
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 160
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 161
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 162
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 163
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 164
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 165
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 166
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 167
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 168
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 169
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 170
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 171
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 172
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 173
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 174
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 175
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 176
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 177
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 178
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 179
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 180
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 181
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 182
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 183
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 185
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 186
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 187
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 188
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 189
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 190
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 191
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 192
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 193
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 194
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 195
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 196
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 197
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 198
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 199
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 201
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 202
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 203
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 204
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 205
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 206
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 207
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 208
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 209
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 210
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 211
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 212
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 213
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 214
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 215
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 216
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 217
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 218
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 219
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 220
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 221
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 222
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 223
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 224
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 225
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 226
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 227
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 228
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 229
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 230
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 231
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 232
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 233
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 234
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 235
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 236
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 237
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 238
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 239
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 240
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 241
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 242
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 243
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 244
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 245
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 246
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 247
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 248
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 249
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 250
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 251
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 252
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 253
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 254
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 255
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 256
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 257
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 258
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 259
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 260
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 261
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 262
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 263
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 264
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 265
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 266
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 267
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 268
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 269
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 270
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 271
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 272
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 273
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 274
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 275
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 276
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 277
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 278
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 279
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 280
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 281
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 282
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 283
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 284
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 285
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 286
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 287
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 288
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 289
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 290
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 291
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 292
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 293
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 294
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 295
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 296
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 297
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 298
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 299
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 301
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 302
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 303
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 304
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 305
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 306
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 307
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 308
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 309
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 310
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 311
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 312
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 313
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 314
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 315
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 316
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 317
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 318
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 319
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 320
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 321
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 322
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 323
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 324
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 325
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 326
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 327
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 328
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 329
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 330
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 331
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 332
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 333
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 334
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 335
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 336
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 337
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 338
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 339
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 340
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 341
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 342
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 343
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 344
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 345
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 346
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 347
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 348
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 349
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 350
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 351
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 352
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 353
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 354
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 355
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 356
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 357
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 358
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 359
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 360
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 361
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 362
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 363
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 364
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 365
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 366
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 367
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 368
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 369
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 370
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 371
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 372
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 373
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 374
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 375
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 376
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 377
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 378
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 379
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 380
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 381
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 382
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 383
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 384
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 385
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 386
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 387
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 388
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 389
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 390
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 391
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 392
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 393
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 394
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 395
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 396
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 397
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 398
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 399
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 400
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 401
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 402
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 403
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 404
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 405
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 406
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 407
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 408
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 409
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 410
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 411
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 412
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 413
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 414
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 415
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 416
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 417
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 418
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 419
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 420
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 421
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 422
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 423
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 424
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 425
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 426
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 427
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 428
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 429
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 430
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 431
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 432
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 433
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 434
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 435
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 436
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 437
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 438
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 439
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 440
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 441
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 442
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 443
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 444
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 445
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 446
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 447
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 448
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 449
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 450
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 451
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 452
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 453
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 454
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 455
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 456
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 457
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 458
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 459
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 460
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 461
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 462
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 463
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 464
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 465
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 466
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 467
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 468
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 469
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 470
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 471
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 472
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 473
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 474
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 475
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 476
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 477
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 478
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 479
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 480
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 481
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 482
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 483
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 484
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 485
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 486
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 487
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 488
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 489
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 490
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 491
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 492
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 493
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 494
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 495
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 496
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 497
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 498
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 499
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
conv_explanations = compute_conv_LIME_explanations(conv_outputs, conv_outputs_perturbed, fn_conv, y_sample_conv)
# Out:
# 0
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 7
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 8
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 11
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 12
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 13
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 14
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 16
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 17
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 18
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 21
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 22
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 23
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 24
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 26
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 27
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 28
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 29
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 31
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 32
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 33
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 34
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 35
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 36
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 37
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 38
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 39
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 41
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 42
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 43
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 44
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 45
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 46
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 47
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 48
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 49
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 51
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 52
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 53
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 54
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 55
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 56
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 57
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 58
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 59
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 60
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 61
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 62
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 65
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 66
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 67
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 68
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 69
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 70
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 71
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 72
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 73
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 74
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 76
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 77
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 78
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 79
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 80
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 81
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 82
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 83
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 84
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 85
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 86
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 87
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 88
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 89
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 90
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 91
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 92
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 93
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 94
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 95
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 96
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 97
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 98
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 99
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 101
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 102
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 103
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 104
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 105
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 106
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 107
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 108
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 109
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 110
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 111
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 112
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 113
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 114
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 115
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 116
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 117
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 118
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 119
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 120
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 121
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 122
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 123
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 124
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 125
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 126
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 127
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 128
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 129
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 130
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 131
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 132
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 133
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 134
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 135
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 136
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 137
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 138
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 139
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 140
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 141
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 142
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 143
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 144
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 145
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 146
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 147
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 148
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 149
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 151
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 152
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 153
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 154
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 155
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 156
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 157
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 158
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 159
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 160
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 161
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 162
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 163
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 164
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 165
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 166
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 167
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 168
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 169
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 170
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 171
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 172
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 173
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 174
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 175
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 176
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 177
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 178
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 179
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 180
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 181
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 182
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 183
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 184
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 185
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 186
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 187
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 188
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 189
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 190
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 191
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 192
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 193
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 194
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 195
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 196
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 197
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 198
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 199
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 201
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 202
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 203
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 204
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 205
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 206
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 207
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 208
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 209
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 210
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 211
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 212
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 213
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 214
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 215
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 216
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 217
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 218
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 219
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 220
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 221
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 222
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 223
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 224
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 225
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 226
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 227
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 228
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 229
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 230
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 231
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 232
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 233
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 234
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 235
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 236
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 237
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 238
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 239
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 240
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 241
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 242
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 243
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 244
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 245
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 246
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 247
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 248
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 249
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 250
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 251
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 252
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 253
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 254
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 255
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 256
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 257
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 258
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 259
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 260
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 261
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 262
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 263
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 264
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 265
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 266
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 267
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 268
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 269
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 270
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 271
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 272
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 273
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 274
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 275
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 276
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 277
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 278
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 279
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 280
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 281
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 282
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 283
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 284
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 285
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 286
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 287
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 288
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 289
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 290
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 291
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 292
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 293
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 294
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 295
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 296
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 297
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 298
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 299
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 301
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 302
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 303
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 304
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 305
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 306
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 307
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 308
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 309
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 310
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 311
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 313
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 314
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 315
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 316
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 317
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 318
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 319
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 320
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 321
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 322
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 323
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 324
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 325
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 326
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 327
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 328
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 329
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 330
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 331
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 332
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 333
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 334
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 335
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 336
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 337
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 338
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 339
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 340
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 341
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 342
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 343
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 344
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 345
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 346
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 347
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 348
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 349
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 350
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 351
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 352
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 353
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 354
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 355
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 356
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 357
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 358
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 359
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 360
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 361
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 362
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 363
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 364
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 365
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 366
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 367
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 368
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 369
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 370
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 371
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 372
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 373
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 374
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 375
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 376
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 377
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 378
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 379
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 380
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 381
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 382
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 383
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 384
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 385
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 386
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 387
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 388
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 389
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 390
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 391
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 392
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 393
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 394
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 395
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 396
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 397
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 398
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 399
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 400
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 401
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 402
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 403
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 404
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 405
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 406
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 407
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 408
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 409
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 410
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 411
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 412
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 413
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 414
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 415
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 416
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 417
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 418
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 419
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 420
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 422
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 423
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 424
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 425
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 426
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 427
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 428
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 429
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 430
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 431
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 432
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 433
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 434
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 435
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 436
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 437
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 438
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 439
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 440
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 441
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 442
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 443
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 444
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 445
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 446
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 447
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 448
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 449
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 450
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 451
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 452
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 453
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 454
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 455
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 456
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 457
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 458
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 459
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 460
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 461
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 462
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 463
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 464
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 465
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 466
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 467
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 468
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 469
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 470
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 471
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 472
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 473
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 474
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 475
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 476
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 477
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 478
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 479
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 480
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 481
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 482
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 483
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 484
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 485
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 486
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 487
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 488
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 489
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 490
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 491
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 492
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 493
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 494
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 495
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 496
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 497
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 498
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 499
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
# Plot a simple average of all explanations for "class of interest" given that the actual digit is "class of interest"
class_of_interest = 6
mean_explanation = LIME_global_mean(explanations, y_sample = y_sample, class_of_interest = class_of_interest)

# Reshape to 28x28
heatmap_average = mean_explanation.reshape(28, 28)

# Plot the heatmap
plt.figure(figsize=(6, 6))
plt.imshow(heatmap_average, cmap='viridis', interpolation='nearest')
plt.colorbar(label='Feature Importance')
plt.title(f'Heatmap of Feature Importances for Class {class_of_interest}')
plt.xlabel('Pixel X')
plt.ylabel('Pixel Y')
plt.show()

# %%
# Plot a simple sqrt sum of all explanations for "class of interest" given that the actual digit is "class of interest"
sum_explanation = LIME_global_paper(explanations, y_sample = y_sample, class_of_interest = 6)

# Reshape to 28x28
heatmap_paper = sum_explanation.reshape(28, 28)

# Plot the heatmap
plt.figure(figsize=(6, 6))
plt.imshow(heatmap_paper, cmap='viridis', interpolation='nearest')
plt.colorbar(label='Feature Importance')
plt.title(f'Heatmap of Feature Importances for Class {class_of_interest}')
plt.xlabel('Pixel X')
plt.ylabel('Pixel Y')
plt.show()

# %%
# Generate explanations
global_exp_norm = LIME_global_normalization(explanations, y_sample = y_sample, class_of_interest = 2)

# Reshape to 28x28
heatmap_norm = global_exp_norm.reshape(28, 28)

# Plot the heatmap
plt.figure(figsize=(6, 6))
plt.imshow(heatmap_norm, cmap='viridis', interpolation='nearest')
plt.colorbar(label='Feature Importance')
plt.title('Heatmap of Global Feature Importances')
plt.xlabel('Pixel X')
plt.ylabel('Pixel Y')
plt.show()

# %%
def mask_top_pixels(data, top_n):
    """
    Mask all but the top_n most important pixels in the data.
    
    Parameters:
        data (np.array): 1D array of feature importances.
        top_n (int): Number of top pixels to retain.
        
    Returns:
        np.array: Masked 1D array with only the top_n pixels retained.
    """
    # Flatten the data to sort
    flat_data = data.flatten()
    # Find the threshold for the top_n largest values
    threshold = np.partition(flat_data, -top_n)[-top_n]
    # Create a mask for pixels above the threshold
    masked_data = np.where(flat_data >= threshold, flat_data, 0)
    return masked_data.reshape(data.shape)

# %%
# Generate explanations
global_exp_norm = LIME_global_normalization(explanations, y_sample=y_sample, class_of_interest=6)

# Reshape to 28x28
heatmap_norm_masked = global_exp_norm.reshape(28, 28)

# Mask all but the top 50 most important pixels
heatmap_norm_masked = mask_top_pixels(heatmap_norm_masked, top_n=50)

# Plot the masked heatmap
plt.figure(figsize=(6, 6))
plt.imshow(heatmap_norm_masked, cmap='viridis', interpolation='nearest')
plt.colorbar(label='Feature Importance')
plt.title('Top 50 Most Important Pixels')
plt.xlabel('Pixel X')
plt.ylabel('Pixel Y')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

def save_and_plot_explanations(exp, y_sample, method='simple', data_type='original', output_prefix='explanations'):
    """
    Save explanations for each class using simple averaging or normalization
    and plot heatmaps for each explanation.
    
    Parameters:
        exp (np.array): Explanation matrix of shape (N, D) for original, or (N, C) for convolutional.
        y_sample (np.array): Array of true class labels of shape (N,).
        method (str): Aggregation method, either 'simple', 'paper', or 'normalization'.
        data_type (str): Type of data to process, either 'original' or 'convolutional'.
        output_prefix (str): Prefix for the output CSV and plot files.
    """
    for class_of_interest in range(10):  # Assuming 10 classes (0–9)
        # Select the aggregation method
        if method == 'simple':
            mean_explanation = LIME_global_mean(exp, y_sample=y_sample, class_of_interest=class_of_interest)
        elif method == 'paper':
            mean_explanation = LIME_global_paper(exp, y_sample=y_sample, class_of_interest=class_of_interest)
        elif method == 'normalization':
            mean_explanation = LIME_global_normalization(exp, y_sample=y_sample, class_of_interest=class_of_interest)
        else:
            raise ValueError("Invalid method. Use 'simple', 'paper', or 'normalization'.")
        
        # Reshape the explanation based on data_type
        if data_type == 'original':
            mean_explanation_reshaped = mean_explanation.reshape(28, 28)  # Assuming input images are 28x28
        elif data_type == 'convolutional':
            # Handle convolutional explanation (N, C)
            num_channels = mean_explanation.shape[-1]  # Number of feature maps (C)
            mean_explanation_reshaped = mean_explanation  # No further reshaping for feature maps
        else:
            raise ValueError("Invalid data_type. Use 'original' or 'convolutional'.")
        
        # Save to CSV
        if data_type == 'original':
            df = pd.DataFrame(mean_explanation_reshaped)
        elif data_type == 'convolutional':
            df = pd.DataFrame(mean_explanation_reshaped)  # Save directly for (C,) explanations

        df.to_csv(f'{output_prefix}_class_{class_of_interest}_{data_type}.csv', index=False, header=True)
        
        # Plot the heatmap or bar chart
        plt.figure(figsize=(6, 6))
        if data_type == 'original':
            plt.imshow(mean_explanation_reshaped, cmap='viridis', interpolation='nearest')
            plt.colorbar(label='Feature Importance')
            plt.title(f'{method.capitalize()} Explanation ({data_type.capitalize()}) for Class {class_of_interest}')
            plt.xlabel('Pixel X')
            plt.ylabel('Pixel Y')
        elif data_type == 'convolutional':
            plt.bar(range(mean_explanation_reshaped.shape[0]), mean_explanation_reshaped)
            plt.title(f'{method.capitalize()} Explanation ({data_type.capitalize()}) for Class {class_of_interest}')
            plt.xlabel('Feature Map Index')
            plt.ylabel('Feature Importance')
        
        # Save the plot
        plt.savefig(f'{output_prefix}_class_{class_of_interest}_{data_type}.png')
        plt.close()  # Close the plot to free memory

# %%
# Generate explanations with pixels
save_and_plot_explanations(explanations, y_sample, method='simple', data_type='original', output_prefix='simple_avg')
save_and_plot_explanations(explanations, y_sample, method='paper', data_type='original', output_prefix='paper')
save_and_plot_explanations(explanations, y_sample, method='normalization', data_type='original', output_prefix='normalized')

# Generate explanations with convolutional feature
save_and_plot_explanations(conv_explanations, y_sample_conv, method='simple', data_type='convolutional', output_prefix='simple_avg')
save_and_plot_explanations(conv_explanations, y_sample_conv, method='paper', data_type='convolutional', output_prefix='paper')
save_and_plot_explanations(conv_explanations, y_sample_conv, method='normalization', data_type='convolutional', output_prefix='normalized')

# %%
from datetime import datetime

def run_one_class(x_train, y_train, x_test, y_test, class_of_interest, n_runs):
    """
    Run pruning for a single class multiple times and save results.

    Parameters:
        x_train (np.array): Training data of shape (N, H, W, C).
        y_train (np.array): Training labels.
        x_test (np.array): Test data of shape (M, H, W, C).
        y_test (np.array): Test labels.
        class_of_interest (int): Class index to run pruning for.
        n_runs (int): Number of runs to perform.
    """
    methods = ['simple_avg', 'paper', 'normalized']
    pruning_ratios = np.linspace(0.1, 0.9, 9)  # Prune 10% to 90%
    all_accuracies = {method: [] for method in methods}  # Store accuracies for all runs

    for _ in range(n_runs):
        for method in methods:
            # Load the explanation CSV for this class and method
            csv_path = f'{method}_class_{class_of_interest}_original.csv'
            importances = pd.read_csv(csv_path).to_numpy()
            
            # Flatten importances to match feature space
            importances_flat = importances.flatten()
            
            # Sort indices in ascending order of importance
            sorted_indices = np.argsort(importances_flat)
            
            accuracies = []
            X_copy = np.copy(x_train)
            
            # Perform pruning for each ratio
            for p in pruning_ratios:
                # Prune the least important features
                threshold_index = int(p * len(sorted_indices))
                prune_indices = sorted_indices[:threshold_index]
                mask = np.ones_like(importances_flat, dtype=bool)
                mask[prune_indices] = False
                mask = mask.reshape(28, 28)
                replicated_mask = np.tile(mask[:, :, np.newaxis], (x_train.shape[0], 1, 1, 1))
                X_copy = X_copy * replicated_mask
                
                # Build and train the model
                model = models.Sequential([
                    # Block 1: Convolution + MaxPooling
                    layers.Input(shape=(28, 28, 1)),  # Explicit Input layer
                    layers.Conv2D(32, (3, 3), activation='relu'),
                    layers.MaxPooling2D((2, 2)),
                    layers.Dropout(0.25),
                
                    # Block 2: Convolution + MaxPooling
                    layers.Conv2D(64, (3, 3), activation='relu'),
                    layers.MaxPooling2D((2, 2)),
                    layers.Dropout(0.25),
                
                    # Fully Connected Layers
                    layers.Flatten(),
                    layers.Dense(128, activation='relu'),
                    layers.Dropout(0.5),
                    layers.Dense(128, activation='relu'),
                    layers.Dropout(0.5),
                    layers.Dense(10, activation='softmax')  # Output layer for classification
                ])
                
                model.compile(optimizer='adam',
                              loss='sparse_categorical_crossentropy',
                              metrics=['accuracy'])
                
                model.fit(X_copy, y_train, epochs=5, validation_split=0.1, verbose=0)
                _, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
                accuracies.append(test_accuracy)
                del model
            
            # Append results for this method
            all_accuracies[method].append(accuracies)

    # Average accuracies across all runs for each method
    avg_accuracies = {method: np.mean(all_accuracies[method], axis=0) for method in methods}

    # Save results to a timestamped CSV file
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    accuracy_save_path = f'pruning_accuracy_class_{class_of_interest}_{timestamp}.csv'
    df = pd.DataFrame({'Pruning Ratio (%)': pruning_ratios * 100})
    for method, avg_acc in avg_accuracies.items():
        df[method.replace('_', ' ').capitalize()] = avg_acc
    df.to_csv(accuracy_save_path, index=False)

    # Plot the average accuracies and save the graph
    plt.figure(figsize=(8, 6))
    for method, avg_acc in avg_accuracies.items():
        plt.plot(pruning_ratios * 100, avg_acc, label=method.replace('_', ' ').capitalize())
    plt.title(f'Average Pruning Accuracy for Class {class_of_interest}')
    plt.xlabel('Pruned Features (%)')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    graph_save_path = f'pruning_accuracy_class_{class_of_interest}_{timestamp}.png'
    plt.savefig(graph_save_path)
    plt.close()

# %%
def run_all_classes(x_train, y_train, x_test, y_test, n_runs):
    """
    Run pruning for all classes using run_one_class.

    Parameters:
        x_train (np.array): Training data of shape (N, H, W, C).
        y_train (np.array): Training labels.
        x_test (np.array): Test data of shape (M, H, W, C).
        y_test (np.array): Test labels.
        n_runs (int): Number of runs to perform for each class.
    """
    for class_of_interest in range(10):
        run_one_class(x_train, y_train, x_test, y_test, class_of_interest, n_runs)

# %%
run_one_class(x_train, y_train, x_test, y_test, class_of_interest = 1, n_runs = 5)

# %%
def run_one_class_convolutional(conv_model, remaining_model, conv_outputs, y_sample_conv, class_of_interest, n_runs):
    methods = ['simple_avg', 'paper', 'normalized']
    pruning_ratios = np.linspace(0.0, 0.9, 10)  # Add 0% pruning for baseline
    all_accuracies = {method: [] for method in methods}

    N, H, W, C = conv_outputs.shape

    for _ in range(n_runs):
        for method in methods:
            csv_path = f'{method}_class_{class_of_interest}_convolutional.csv'
            importances = pd.read_csv(csv_path).to_numpy()

            # Check importance shape
            if importances.shape == (C, 1):
                channel_importance = importances.flatten()
            elif importances.shape == (C,):
                channel_importance = importances
            elif importances.shape == (H, W, C):
                channel_importance = importances.mean(axis=(0, 1))
            else:
                raise ValueError(f"Unsupported importance shape {importances.shape}.")

            sorted_indices = np.argsort(channel_importance)

            accuracies = []
            for p in pruning_ratios:
                pruned_outputs = np.copy(conv_outputs)

                if p > 0:
                    threshold_index = int(p * C)
                    prune_indices = sorted_indices[:threshold_index]
                    pruned_outputs[..., prune_indices] = 0  # Zero out pruned feature maps

                predictions = remaining_model.predict(pruned_outputs, verbose=0)
                test_accuracy = np.mean(np.argmax(predictions, axis=1) == y_sample_conv)
                accuracies.append(test_accuracy)

            all_accuracies[method].append(accuracies)

    avg_accuracies = {method: np.mean(all_accuracies[method], axis=0) for method in methods}

    # Save and plot results
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    accuracy_save_path = f'pruning_accuracy_class_{class_of_interest}_convolutional_{timestamp}.csv'
    df = pd.DataFrame({'Pruning Ratio (%)': pruning_ratios * 100})
    for method, avg_acc in avg_accuracies.items():
        df[method.replace('_', ' ').capitalize()] = avg_acc
    df.to_csv(accuracy_save_path, index=False)

    plt.figure(figsize=(8, 6))
    for method, avg_acc in avg_accuracies.items():
        plt.plot(pruning_ratios * 100, avg_acc, label=method.replace('_', ' ').capitalize())
    plt.title(f'Average Pruning Accuracy for Class {class_of_interest} (Convolutional)')
    plt.xlabel('Pruned Feature Maps (%)')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    graph_save_path = f'pruning_accuracy_class_{class_of_interest}_convolutional_{timestamp}.png'
    plt.savefig(graph_save_path)
    plt.close()

# %%
run_one_class_convolutional(
    conv_model=conv_model,
    remaining_model=remaining_model,
    conv_outputs=conv_outputs,
    y_sample_conv=y_sample_conv,
    class_of_interest=0,
    n_runs=5
)

# %%
def build_pruning_graphs(x_train, y_train, x_test, y_test):
    """
    Build pruning graphs for all classes using saved explanation CSV files.
    
    Parameters:
        x_train (np.array): Training data of shape (N, H, W, C).
        y_train (np.array): Training labels.
        x_test (np.array): Test data of shape (M, H, W, C).
        y_test (np.array): Test labels.
    """
    methods = ['simple_avg', 'paper', 'normalized']
    pruning_ratios = np.linspace(0.1, 0.9, 9)  # Prune 10% to 90%
    results = {method: [] for method in methods}  # Store accuracies for each method

    for class_of_interest in range(10):
        plt.figure(figsize=(8, 6))
        for method in methods:
            # Load the explanation CSV for this class and method
            csv_path = f'{method}_class_{class_of_interest}.csv'
            importances = pd.read_csv(csv_path).to_numpy()
            
            # Flatten importances to match feature space
            importances_flat = importances.flatten()
            
            # Sort indices in ascending order of importance
            sorted_indices = np.argsort(importances_flat)
            
            accuracies = []
            X_copy = np.copy(x_train)
            
            # Perform pruning for each ratio
            for p in pruning_ratios:
                # Prune the least important features
                threshold_index = int(p * len(sorted_indices))
                prune_indices = sorted_indices[:threshold_index]
                mask = np.ones_like(importances_flat, dtype=bool)
                mask[prune_indices] = False
                mask = mask.reshape(28, 28)
                replicated_mask = np.tile(mask[:, :, np.newaxis], (x_train.shape[0], 1, 1, 1))
                X_copy = X_copy * replicated_mask
                
                # Build and train the model
                model = models.Sequential([
                    # Block 1: Convolution + MaxPooling
                    layers.Input(shape=(28, 28, 1)),  # Explicit Input layer
                    layers.Conv2D(32, (3, 3), activation='relu'),
                    layers.MaxPooling2D((2, 2)),
                    layers.Dropout(0.25),
                
                    # Block 2: Convolution + MaxPooling
                    layers.Conv2D(64, (3, 3), activation='relu'),
                    layers.MaxPooling2D((2, 2)),
                    layers.Dropout(0.25),
                
                    # Fully Connected Layers
                    layers.Flatten(),
                    layers.Dense(128, activation='relu'),
                    layers.Dropout(0.5),
                    layers.Dense(128, activation='relu'),
                    layers.Dropout(0.5),
                    layers.Dense(10, activation='softmax')  # Output layer for classification
                ])
                
                model.compile(optimizer='adam',
                              loss='sparse_categorical_crossentropy',
                              metrics=['accuracy'])
                
                model.fit(X_copy, y_train, epochs=5, validation_split=0.1, verbose=0)
                _, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
                accuracies.append(test_accuracy)
                del model
            
            # Store the results and plot the line for this method
            results[method].append(accuracies)
            plt.plot(pruning_ratios * 100, accuracies, label=method.replace('_', ' ').capitalize())
            

        # Save the accuracies for this class in a single CSV
        accuracy_save_path = f'pruning_accuracy_class_{class_of_interest}.csv'
        df = pd.DataFrame({'Pruning Ratio (%)': pruning_ratios * 100})
        for method in methods:
            df[method.replace('_', ' ').capitalize()] = results[method][class_of_interest]
        df.to_csv(accuracy_save_path, index=False)

        # Configure and save the graph for this class
        plt.title(f'Pruning Accuracy for Class {class_of_interest}')
        plt.xlabel('Pruned Features (%)')
        plt.ylabel('Accuracy')
        plt.legend()
        plt.grid(True)
        plt.savefig(f'pruning_accuracy_class_{class_of_interest}.png')
        plt.close()

# %%
build_pruning_graphs(x_train, y_train, x_test, y_test)
